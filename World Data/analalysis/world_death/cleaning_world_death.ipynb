# %%
import pandas as pd 
import numpy as np
df = pd.read_csv('../../world_death.csv')
df.head()
# governance.dtypes
# governance.describe(include="all")
# Out:
#    Year Country Name Country Code Life Expectancy at birth (total years)  \
# 0  2016  Afghanistan          AFG                                 63.763
# 1  2017  Afghanistan          AFG                                  64.13
# 2  2020  Afghanistan          AFG                                     ..
# 3  2018  Afghanistan          AFG                                 64.486
# 4  2019  Afghanistan          AFG                                 64.833
#
#   Lifetime risk of maternal death (%)  \
# 0                     3.3309138614947
# 1                    3.06359325193536
# 2                                  ..
# 3                                  ..
# 4                                  ..
#
#   Maternal mortality ratio (per 100,000 live births)  \
# 0                                               1194
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Mortality cauased by road traffic injury (per 100,000 population)  \
# 0                                               14.8
# 1                                               15.1
# 2                                                 ..
# 3                                               14.2
# 4                                               15.9
#
#   Mortality from CVD, cancer, diabetes or CRD between ages 30 and 70 (%)  \
# 0                                               35.6
# 1                                               35.5
# 2                                                 ..
# 3                                               35.4
# 4                                               35.3
#
#   Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)  \
# 0                                              211.1
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Mortality rate attributed to unintentional poisoning (per 100,000 population)  \
# 0                                                  1
# 1                                                1.1
# 2                                                 ..
# 3                                                0.9
# 4                                                  1
#
#   Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)  \
# 0                                               13.9
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Mortality rate, infant (per 1,000 live births)  \
# 0                                           51.3
# 1                                           49.5
# 2                                             45
# 3                                           47.9
# 4                                           46.4
#
#   Mortality rate, neonatal (per 1,000 live births)  \
# 0                                             39.3
# 1                                             38.2
# 2                                             35.2
# 3                                             37.2
# 4                                             36.1
#
#   Mortality rate, under-5 (per 1,000 live births)  \
# 0                                            67.5
# 1                                            64.8
# 2                                              58
# 3                                            62.3
# 4                                            60.1
#
#   Suicide mortality rate (per 100,000 population)  \
# 0                                               4
# 1                                             4.1
# 2                                              ..
# 3                                             4.1
# 4                                             4.1
#
#   Intentional homicides (per 100,000 people) GDP (current US$)
# 0                               6.5511634561  18116562464.9088
# 1                               6.6784014409  18753469630.2586
# 2                                         ..  20116137325.8206
# 3                               6.6555611518  18053228578.8878
# 4                                         ..  18799450742.7823

# %%
df=df.replace({'..':np.NaN}).fillna(value=np.NaN)#replace all cells with .. with None so that python can evaluate it as missing value
# df.fillna(value=np.NaN,inplace=True)
df.head()
# Out:
#    Year Country Name Country Code Life Expectancy at birth (total years)  \
# 0  2016  Afghanistan          AFG                                 63.763
# 1  2017  Afghanistan          AFG                                  64.13
# 2  2020  Afghanistan          AFG                                    NaN
# 3  2018  Afghanistan          AFG                                 64.486
# 4  2019  Afghanistan          AFG                                 64.833
#
#   Lifetime risk of maternal death (%)  \
# 0                     3.3309138614947
# 1                    3.06359325193536
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   Maternal mortality ratio (per 100,000 live births)  \
# 0                                               1194
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Mortality cauased by road traffic injury (per 100,000 population)  \
# 0                                               14.8
# 1                                               15.1
# 2                                                NaN
# 3                                               14.2
# 4                                               15.9
#
#   Mortality from CVD, cancer, diabetes or CRD between ages 30 and 70 (%)  \
# 0                                               35.6
# 1                                               35.5
# 2                                                NaN
# 3                                               35.4
# 4                                               35.3
#
#   Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)  \
# 0                                              211.1
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Mortality rate attributed to unintentional poisoning (per 100,000 population)  \
# 0                                                  1
# 1                                                1.1
# 2                                                NaN
# 3                                                0.9
# 4                                                  1
#
#   Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)  \
# 0                                               13.9
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Mortality rate, infant (per 1,000 live births)  \
# 0                                           51.3
# 1                                           49.5
# 2                                             45
# 3                                           47.9
# 4                                           46.4
#
#   Mortality rate, neonatal (per 1,000 live births)  \
# 0                                             39.3
# 1                                             38.2
# 2                                             35.2
# 3                                             37.2
# 4                                             36.1
#
#   Mortality rate, under-5 (per 1,000 live births)  \
# 0                                            67.5
# 1                                            64.8
# 2                                              58
# 3                                            62.3
# 4                                            60.1
#
#   Suicide mortality rate (per 100,000 population)  \
# 0                                               4
# 1                                             4.1
# 2                                             NaN
# 3                                             4.1
# 4                                             4.1
#
#   Intentional homicides (per 100,000 people) GDP (current US$)
# 0                               6.5511634561  18116562464.9088
# 1                               6.6784014409  18753469630.2586
# 2                                        NaN  20116137325.8206
# 3                               6.6555611518  18053228578.8878
# 4                                        NaN  18799450742.7823

# %%
df.dtypes
# Out:
# Year                                                                                                            int64
# Country Name                                                                                                   object
# Country Code                                                                                                   object
# Life Expectancy at birth (total years)                                                                         object
# Lifetime risk of maternal death (%)                                                                            object
# Maternal mortality ratio (per 100,000 live births)                                                             object
# Mortality cauased by road traffic injury (per 100,000 population)                                              object
# Mortality from CVD, cancer, diabetes or CRD between ages 30 and 70 (%)                                         object
# Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)    object
# Mortality rate attributed to unintentional poisoning (per 100,000 population)                                  object
# Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)      object
# Mortality rate, infant (per 1,000 live births)                                                                 object
# Mortality rate, neonatal (per 1,000 live births)                                                               object
# Mortality rate, under-5 (per 1,000 live births)                                                                object
# Suicide mortality rate (per 100,000 population)                                                                object
# Intentional homicides (per 100,000 people)                                                                     object
# GDP (current US$)                                                                                              object
# dtype: object

# %% [markdown]
# # changes data types accordingly

# %%
object_list = df.select_dtypes(include=['object']).columns.to_list()[2:]
# print(object_list)
df[object_list]=df[object_list].astype(float)
df.dtypes
# Out:
# Year                                                                                                             int64
# Country Name                                                                                                    object
# Country Code                                                                                                    object
# Life Expectancy at birth (total years)                                                                         float64
# Lifetime risk of maternal death (%)                                                                            float64
# Maternal mortality ratio (per 100,000 live births)                                                             float64
# Mortality cauased by road traffic injury (per 100,000 population)                                              float64
# Mortality from CVD, cancer, diabetes or CRD between ages 30 and 70 (%)                                         float64
# Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)    float64
# Mortality rate attributed to unintentional poisoning (per 100,000 population)                                  float64
# Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)      float64
# Mortality rate, infant (per 1,000 live births)                                                                 float64
# Mortality rate, neonatal (per 1,000 live births)                                                               float64
# Mortality rate, under-5 (per 1,000 live births)                                                                float64
# Suicide mortality rate (per 100,000 population)                                                                float64
# Intentional homicides (per 100,000 people)                                                                     float64
# GDP (current US$)                                                                                              float64
# dtype: object

# %%
dic = {2016:0,2017:1,2018:2,2019:3,2020:4}
df['Age']=df['Year'].map(dic)
df
# Out:
#       Year Country Name Country Code  Life Expectancy at birth (total years)  \
# 0     2016  Afghanistan          AFG                                  63.763
# 1     2017  Afghanistan          AFG                                  64.130
# 2     2020  Afghanistan          AFG                                     NaN
# 3     2018  Afghanistan          AFG                                  64.486
# 4     2019  Afghanistan          AFG                                  64.833
# ...    ...          ...          ...                                     ...
# 1325  2020     Zimbabwe          ZWE                                     NaN
# 1326  2016     Zimbabwe          ZWE                                  60.294
# 1327  2019     Zimbabwe          ZWE                                  61.490
# 1328  2017     Zimbabwe          ZWE                                  60.812
# 1329  2018     Zimbabwe          ZWE                                  61.195
#
#       Lifetime risk of maternal death (%)  \
# 0                                3.330914
# 1                                3.063593
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 1325                                  NaN
# 1326                             1.911101
# 1327                                  NaN
# 1328                             1.815294
# 1329                                  NaN
#
#       Maternal mortality ratio (per 100,000 live births)  \
# 0                                                1194.0
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1325                                                NaN
# 1326                                                NaN
# 1327                                                NaN
# 1328                                                NaN
# 1329                                                NaN
#
#       Mortality cauased by road traffic injury (per 100,000 population)  \
# 0                                                  14.8
# 1                                                  15.1
# 2                                                   NaN
# 3                                                  14.2
# 4                                                  15.9
# ...                                                 ...
# 1325                                                NaN
# 1326                                               39.9
# 1327                                               41.2
# 1328                                               40.1
# 1329                                               40.6
#
#       Mortality from CVD, cancer, diabetes or CRD between ages 30 and 70 (%)  \
# 0                                                  35.6
# 1                                                  35.5
# 2                                                   NaN
# 3                                                  35.4
# 4                                                  35.3
# ...                                                 ...
# 1325                                                NaN
# 1326                                               30.4
# 1327                                               28.4
# 1328                                               29.3
# 1329                                               28.5
#
#       Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)  \
# 0                                                 211.1
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1325                                                NaN
# 1326                                              133.0
# 1327                                                NaN
# 1328                                                NaN
# 1329                                                NaN
#
#       Mortality rate attributed to unintentional poisoning (per 100,000 population)  \
# 0                                                   1.0
# 1                                                   1.1
# 2                                                   NaN
# 3                                                   0.9
# 4                                                   1.0
# ...                                                 ...
# 1325                                                NaN
# 1326                                                4.2
# 1327                                                3.5
# 1328                                                3.7
# 1329                                                3.8
#
#       Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)  \
# 0                                                  13.9
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1325                                                NaN
# 1326                                               24.6
# 1327                                                NaN
# 1328                                                NaN
# 1329                                                NaN
#
#       Mortality rate, infant (per 1,000 live births)  \
# 0                                               51.3
# 1                                               49.5
# 2                                               45.0
# 3                                               47.9
# 4                                               46.4
# ...                                              ...
# 1325                                            37.9
# 1326                                            40.8
# 1327                                            38.1
# 1328                                            39.9
# 1329                                            38.8
#
#       Mortality rate, neonatal (per 1,000 live births)  \
# 0                                                 39.3
# 1                                                 38.2
# 2                                                 35.2
# 3                                                 37.2
# 4                                                 36.1
# ...                                                ...
# 1325                                              25.7
# 1326                                              27.4
# 1327                                              26.2
# 1328                                              27.0
# 1329                                              26.6
#
#       Mortality rate, under-5 (per 1,000 live births)  \
# 0                                                67.5
# 1                                                64.8
# 2                                                58.0
# 3                                                62.3
# 4                                                60.1
# ...                                               ...
# 1325                                             53.9
# 1326                                             58.7
# 1327                                             54.2
# 1328                                             57.0
# 1329                                             54.8
#
#       Suicide mortality rate (per 100,000 population)  \
# 0                                                 4.0
# 1                                                 4.1
# 2                                                 NaN
# 3                                                 4.1
# 4                                                 4.1
# ...                                               ...
# 1325                                              NaN
# 1326                                             16.8
# 1327                                             14.1
# 1328                                             15.0
# 1329                                             14.0
#
#       Intentional homicides (per 100,000 people)  GDP (current US$)  Age
# 0                                       6.551163       1.811656e+10    0
# 1                                       6.678401       1.875347e+10    1
# 2                                            NaN       2.011614e+10    4
# 3                                       6.655561       1.805323e+10    2
# 4                                            NaN       1.879945e+10    3
# ...                                          ...                ...  ...
# 1325                                         NaN       1.805117e+10    4
# 1326                                         NaN       2.054868e+10    0
# 1327                                         NaN       1.928429e+10    3
# 1328                                         NaN       1.758489e+10    1
# 1329                                         NaN       1.811554e+10    2
#
# [1330 rows x 18 columns]

# %%
def fill_missing_values(group):
    value_columns = group.select_dtypes(include='number').columns

    for value_col in value_columns:
        values = group[value_col]
        known_values_mask = values.notnull()
        if known_values_mask.sum() > 0:  # If there is at least one known value
            if known_values_mask.sum() > 1:  # If there are more than one known values
                sorted_group = group.sort_values('Age')
                x_known = group.loc[known_values_mask, 'Age']
                y_known = group.loc[known_values_mask, value_col]
                a = (y_known.iloc[-1] - y_known.iloc[0]) / (x_known.iloc[-1] - x_known.iloc[0])
                b = y_known.iloc[0] - (a * x_known.iloc[0])

                missing_mask = values.isnull()
                x_missing = group.loc[missing_mask, 'Age']
                group.loc[missing_mask, value_col] = a * x_missing + b
            else:  # If there is only one known value
                known_value = values[known_values_mask].iloc[0]
                group[value_col].fillna(known_value, inplace=True)


    return group
final = df.reset_index().groupby('Country Name',group_keys=True).apply(fill_missing_values).reset_index(drop=True).drop('index',axis=1)
final
# Out:
#       Year Country Name Country Code  Life Expectancy at birth (total years)  \
# 0     2016  Afghanistan          AFG                               63.763000
# 1     2017  Afghanistan          AFG                               64.130000
# 2     2020  Afghanistan          AFG                               65.189667
# 3     2018  Afghanistan          AFG                               64.486000
# 4     2019  Afghanistan          AFG                               64.833000
# ...    ...          ...          ...                                     ...
# 1325  2020     Zimbabwe          ZWE                               62.096000
# 1326  2016     Zimbabwe          ZWE                               60.294000
# 1327  2019     Zimbabwe          ZWE                               61.490000
# 1328  2017     Zimbabwe          ZWE                               60.812000
# 1329  2018     Zimbabwe          ZWE                               61.195000
#
#       Lifetime risk of maternal death (%)  \
# 0                                3.330914
# 1                                3.063593
# 2                                2.261631
# 3                                2.796273
# 4                                2.528952
# ...                                   ...
# 1325                             1.527874
# 1326                             1.911101
# 1327                             1.623681
# 1328                             1.815294
# 1329                             1.719488
#
#       Maternal mortality ratio (per 100,000 live births)  \
# 0                                                1194.0
# 1                                                1194.0
# 2                                                1194.0
# 3                                                1194.0
# 4                                                1194.0
# ...                                                 ...
# 1325                                                NaN
# 1326                                                NaN
# 1327                                                NaN
# 1328                                                NaN
# 1329                                                NaN
#
#       Mortality cauased by road traffic injury (per 100,000 population)  \
# 0                                             14.800000
# 1                                             15.100000
# 2                                             16.266667
# 3                                             14.200000
# 4                                             15.900000
# ...                                                 ...
# 1325                                          41.300000
# 1326                                          39.900000
# 1327                                          41.200000
# 1328                                          40.100000
# 1329                                          40.600000
#
#       Mortality from CVD, cancer, diabetes or CRD between ages 30 and 70 (%)  \
# 0                                                  35.6
# 1                                                  35.5
# 2                                                  35.2
# 3                                                  35.4
# 4                                                  35.3
# ...                                                 ...
# 1325                                               26.6
# 1326                                               30.4
# 1327                                               28.4
# 1328                                               29.3
# 1329                                               28.5
#
#       Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)  \
# 0                                                 211.1
# 1                                                 211.1
# 2                                                 211.1
# 3                                                 211.1
# 4                                                 211.1
# ...                                                 ...
# 1325                                              133.0
# 1326                                              133.0
# 1327                                              133.0
# 1328                                              133.0
# 1329                                              133.0
#
#       Mortality rate attributed to unintentional poisoning (per 100,000 population)  \
# 0                                                   1.0
# 1                                                   1.1
# 2                                                   1.0
# 3                                                   0.9
# 4                                                   1.0
# ...                                                 ...
# 1325                                                3.4
# 1326                                                4.2
# 1327                                                3.5
# 1328                                                3.7
# 1329                                                3.8
#
#       Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)  \
# 0                                                  13.9
# 1                                                  13.9
# 2                                                  13.9
# 3                                                  13.9
# 4                                                  13.9
# ...                                                 ...
# 1325                                               24.6
# 1326                                               24.6
# 1327                                               24.6
# 1328                                               24.6
# 1329                                               24.6
#
#       Mortality rate, infant (per 1,000 live births)  \
# 0                                               51.3
# 1                                               49.5
# 2                                               45.0
# 3                                               47.9
# 4                                               46.4
# ...                                              ...
# 1325                                            37.9
# 1326                                            40.8
# 1327                                            38.1
# 1328                                            39.9
# 1329                                            38.8
#
#       Mortality rate, neonatal (per 1,000 live births)  \
# 0                                                 39.3
# 1                                                 38.2
# 2                                                 35.2
# 3                                                 37.2
# 4                                                 36.1
# ...                                                ...
# 1325                                              25.7
# 1326                                              27.4
# 1327                                              26.2
# 1328                                              27.0
# 1329                                              26.6
#
#       Mortality rate, under-5 (per 1,000 live births)  \
# 0                                                67.5
# 1                                                64.8
# 2                                                58.0
# 3                                                62.3
# 4                                                60.1
# ...                                               ...
# 1325                                             53.9
# 1326                                             58.7
# 1327                                             54.2
# 1328                                             57.0
# 1329                                             54.8
#
#       Suicide mortality rate (per 100,000 population)  \
# 0                                            4.000000
# 1                                            4.100000
# 2                                            4.133333
# 3                                            4.100000
# 4                                            4.100000
# ...                                               ...
# 1325                                        11.200000
# 1326                                        16.800000
# 1327                                        14.100000
# 1328                                        15.000000
# 1329                                        14.000000
#
#       Intentional homicides (per 100,000 people)  GDP (current US$)  Age
# 0                                       6.551163       1.811656e+10    0
# 1                                       6.678401       1.875347e+10    1
# 2                                       6.759959       2.011614e+10    4
# 3                                       6.655561       1.805323e+10    2
# 4                                       6.707760       1.879945e+10    3
# ...                                          ...                ...  ...
# 1325                                         NaN       1.805117e+10    4
# 1326                                         NaN       2.054868e+10    0
# 1327                                         NaN       1.928429e+10    3
# 1328                                         NaN       1.758489e+10    1
# 1329                                         NaN       1.811554e+10    2
#
# [1330 rows x 18 columns]

# %%
final.sort_values(['Country Name', 'Age'],inplace=True)

# %%
final.fillna(value=0,inplace=True)

# %%
from ydata_profiling import  ProfileReport
correlations_options = {
    'pearson': {
        'correlation_threshold':0.5,
        'matrix':'dendrogram',
        'calculate':True,
        'numeric_only':True
    }
}

prof = ProfileReport(final,title='eda',explorative=True,dark_mode=True,minimal=True, correlations = correlations_options)
prof.to_file('output_file_cleaned.html')
# prof
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\amen\AppData\Local\Programs\Python\Python311\Lib\site-packages\ydata_profiling\model\pandas\correlations_pandas.py:36: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return df.corr(method="pearson")
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
final.to_csv('world_death_cleaned.csv')
